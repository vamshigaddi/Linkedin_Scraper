# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
URL='https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=9285caf4-6113-498c-9bd9-6885dbb348a6'

# %%
# Headers for request
HEADERS=({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0','Accept-Language':'en-US,en;q=0.5'})# add your user agent

# %%
#HTTP request
web_page=requests.get(URL,headers=HEADERS)

# %%
web_page
# Out:
# <Response [200]>

# %%
web_page.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57
# ...

# %%
type(web_page.content)
# Out:
# bytes

# %%
soup=BeautifulSoup(web_page.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# Fetching links that are in 'a' tags (this is html)

# %%
class_attribute = ["_1fQZEK", 'target="_blank"', 'rel="noopener noreferrer"']

# %%
links = soup.find_all('a', attrs={'class': class_attribute})

# %%
links
# Out:
# [<a class="_1fQZEK" href="/samsung-galaxy-f13-waterfall-blue-64-gb/p/itm583ef432b2b0c?pid=MOBGENJWBPFYJSFT&amp;lid=LSTMOBGENJWBPFYJSFTP8FGOC&amp;marketplace=FLIPKART&amp;q=mobiles&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&amp;otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&amp;fm=organic&amp;iid=e0213e98-1861-4b9c-9fb4-7f5230274871.MOBGENJWBPFYJSFT.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=8whv9cug2o0000001701081690664&amp;qH=eb4af0bf07c16429" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/q/l/l/-original-imagueeyshyqzbfh.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div cl
# ...

# %%
links[0]
# Out:
# <a class="_1fQZEK" href="/samsung-galaxy-f13-waterfall-blue-64-gb/p/itm583ef432b2b0c?pid=MOBGENJWBPFYJSFT&amp;lid=LSTMOBGENJWBPFYJSFTP8FGOC&amp;marketplace=FLIPKART&amp;q=mobiles&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&amp;otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&amp;fm=organic&amp;iid=e0213e98-1861-4b9c-9fb4-7f5230274871.MOBGENJWBPFYJSFT.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=8whv9cug2o0000001701081690664&amp;qH=eb4af0bf07c16429" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/q/l/l/-original-imagueeyshyqzbfh.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div cla
# ...

# %%
links[0].get('href') # extracting link
# Out:
# '/samsung-galaxy-f13-waterfall-blue-64-gb/p/itm583ef432b2b0c?pid=MOBGENJWBPFYJSFT&lid=LSTMOBGENJWBPFYJSFTP8FGOC&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_1&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&fm=organic&iid=e0213e98-1861-4b9c-9fb4-7f5230274871.MOBGENJWBPFYJSFT.SEARCH&ppt=None&ppn=None&ssid=8whv9cug2o0000001701081690664&qH=eb4af0bf07c16429'

# %%
link=links[0].get('href')

# %%
product_list='https://flipkart.com'+link

# %%
product_list
# Out:
# 'https://flipkart.com/samsung-galaxy-f13-waterfall-blue-64-gb/p/itm583ef432b2b0c?pid=MOBGENJWBPFYJSFT&lid=LSTMOBGENJWBPFYJSFTP8FGOC&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_1&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&fm=organic&iid=e0213e98-1861-4b9c-9fb4-7f5230274871.MOBGENJWBPFYJSFT.SEARCH&ppt=None&ppn=None&ssid=8whv9cug2o0000001701081690664&qH=eb4af0bf07c16429'

# %%
new_webpage=requests.get(product_list,headers=HEADERS)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
new_soup=BeautifulSoup(new_webpage.content,'html.parser')

# %%
# to extract title of product
new_soup.find("span",attrs={"class":"B_NuCI"}).text.strip()
# Out:
# 'SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)\xa0\xa0(4 GB RAM)'

# %%
new_soup.find("div",attrs={"class":"_30jeq3 _16Jk6d"}).text
# Out:
# '₹8,199'

# %%
new_soup.find("div",attrs={"class":"_3LWZlK"}).text
# Out:
# '4.3'

# %%
new_soup.find("span",attrs={"class":"_2_R_DZ"}).text.split()[3]
# Out:
# '10,622'

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"class":'B_NuCI'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("div", attrs={'class':'_30jeq3 _16Jk6d'}).string.strip()

    except AttributeError:

        #try:
            # If there is some deal price
            #price = soup.find("div", attrs={'id':'priceblock_dealprice'}).string.strip()

        #except:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("div", attrs={'class':'_3LWZlK'}).text.strip()
    
    except AttributeError:
        #try:
           # rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        #except:
            rating = ""

    return rating

# Function to extract Number of User Reviews
#def get_review_count(soup):
    #try:
        #review_count = soup.find("span", attrs={'id':'_2_R_DZ'})
        #review_count=review_count.text.split()[3]

   # except AttributeError:
      #  review_count = ""

    #return review_count





# Function to extract Availability Status
#def get_availability(soup):
    #try:
        #available = soup.find("div", attrs={'id':'availability'})
        #available = available.find("span").string.strip()

    #except AttributeError:
       # available = "Not Available"

   # return available

# %%
if __name__ == '__main__':
    
    url=f'https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=9285caf4-6113-498c-9bd9-6885dbb348a6&page='
    for i in range(1,3):
        # add your user agent 
        HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})
        # The webpage URL
        URL = url + str(i)
        # HTTP Request
        webpage = requests.get(URL, headers=HEADERS)

        # Soup Object containing all data
        soup = BeautifulSoup(webpage.content, "html.parser")

        # Fetch links as List of Tag Objects
        links = soup.find_all('a', attrs={'class': class_attribute})

        # Store the links
        links_list = []

        # Loop for extracting links from Tag Objects
        for link in links:
                links_list.append(link.get('href'))

        d = {"title":[], "price":[], "rating":[]} #"availability":[]}

        # Loop for extracting product details from each link 
        for link in links_list:
            new_webpage = requests.get("https://www.flipkart.com" + link, headers=HEADERS)

            new_soup = BeautifulSoup(new_webpage.content, "html.parser")

            # Function calls to display all necessary product information
            d['title'].append(get_title(new_soup))
            d['price'].append(get_price(new_soup))
            d['rating'].append(get_rating(new_soup))
            #d['reviews'].append(get_review_count(new_soup))
            #d['availability'].append(get_availability(new_soup))

        
        flipkart_df = pd.DataFrame.from_dict(d)
        #amazon_df['title'].replace('', np.nan, inplace=True)
        flipkart_df = flipkart_df.dropna(subset=['title'])
        #amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
flipkart_df
# Out:
#                                                 title    price rating
# 0   MOTOROLA Edge 40 Neo (Caneel Bay, 128 GB)  (8 ...  ₹22,999    4.4
# 1   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...  ₹21,708    4.4
# 2   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128...  ₹19,789    4.4
# 3          POCO C55 (Power Black, 128 GB)  (6 GB RAM)   ₹7,799    4.1
# 4    POCO M6 Pro 5G (Power Black, 128 GB)  (4 GB RAM)  ₹10,999    4.3
# 5              POCO M5 (Icy Blue, 128 GB)  (6 GB RAM)   ₹8,999    4.2
# 6           REDMI 12 (Jade Black, 128 GB)  (4 GB RAM)   ₹9,299    4.3
# 7                       APPLE iPhone 12 (Blue, 64 GB)  ₹40,999    4.6
# 8           POCO C51 (Power Black, 64 GB)  (4 GB RAM)   ₹6,249      4
# 9   MOTOROLA g84 5G (Viva Magneta, 256 GB)  (12 GB...  ₹18,999    4.2
# 10  MOTOROLA Edge 40 Neo (Soothing Sea, 256 GB)  (...  ₹24,999    4.3
# 11            POCO C55 (Cool Blue, 64 GB)  (4 GB RAM)   ₹6,799    4.2
# ...
